# %% [markdown]
# <a href="https://colab.research.google.com/github/frankyeh/Brain-Data/blob/gh-pages/download_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, os, re;
owner, repo, tag = "data-hcp", "lifespan", "hcp-ya"; # Define repo details
pattern = r".*\.fz$"; # select all .fz files
api_url = f"https://api.github.com/repos/{owner}/{repo}/releases/tags/{tag}"; # API endpoint
def dl(u, p):
    try:
        r = requests.get(u, stream=True); r.raise_for_status(); s = int(r.headers.get('content-length', 0)); d = 0;
        with open(p, 'wb') as f:
            for c in r.iter_content(1024): f.write(c); d += len(c);
            print(f"\rDownloaded {os.path.basename(p)}: {(d/s)*100:.2f}%", end='');
        print("\nDone")
    except Exception as e: print(f"Error: {e}")
try:
    assets = requests.get(api_url).json().get('assets', []);
    [dl(asset['browser_download_url'], os.path.join(os.getcwd(), asset['name'])) for asset in assets if re.match(pattern, asset['name'])]
except Exception as e: print(f"Error fetching/processing assets: {e}")
# Out:
# Downloaded 101006.qsdr.fz: 100.00%
# Done
# Downloaded 100610.qsdr.fz: 100.00%
# Done
# Downloaded 100206.qsdr.fz: 100.00%
# Done
# Downloaded 100307.qsdr.fz: 100.00%
# Done
# Downloaded 100408.qsdr.fz: 100.00%
# Done
# Downloaded 101107.qsdr.fz: 100.00%
# Done
# Downloaded 101309.qsdr.fz: 100.00%
# Done
# Downloaded 101410.qsdr.fz: 100.00%
# Done
# Downloaded 101915.qsdr.fz: 100.00%
# Done
# Downloaded 102008.qsdr.fz: 100.00%
# Done
# Downloaded 102109.qsdr.fz: 100.00%
# Done
# Downloaded 102311.qsdr.fz: 100.00%
# Done
# Downloaded 102513.qsdr.fz: 100.00%
# Done
# Downloaded 102614.qsdr.fz: 100.00%
# Done
# Downloaded 102715.qsdr.fz: 100.00%
# Done
# Downloaded 102816.qsdr.fz: 100.00%
# Done
# Downloaded 103010.qsdr.fz: 100.00%
# Done
# Downloaded 103111.qsdr.fz: 100.00%
# Done
# Downloaded 103212.qsdr.fz: 100.00%
# Done
# Downloaded 103414.qsdr.fz: 100.00%
# Done
# Downloaded 103515.qsdr.fz: 100.00%
# Done
# Downloaded 103818.qsdr.fz: 100.00%
# Done
# Downloaded 104012.qsdr.fz: 100.00%
# Done
